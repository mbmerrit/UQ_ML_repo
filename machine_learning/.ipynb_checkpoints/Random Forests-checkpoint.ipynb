# %%
import sklearn as sklearn
from sklearn import tree

from scipy.io import loadmat 
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# # Classification and Decision Trees for the PIMA diabetes dataset

# %%
PIMA = loadmat('Pima-Data-Adjusted.mat')
PIMA_data = PIMA['data']
features, variables = PIMA_data.shape
plt.pcolor(PIMA_data)

# Need to split into training and validation data
split = .7 # 70% training/validation split
split_idx = int(np.round(features*split))
x_train = PIMA_data[:split_idx, :-1]
y_train = PIMA_data[:split_idx,-1]
x_test = PIMA_data[split_idx:, :-1]
y_test = PIMA_data[split_idx:,-1]

# %%
# Now we set up and train the classification tree model, no tuning of hyperparameters yet
clf = sklearn.tree.DecisionTreeClassifier()
clf = clf.fit(x_train, y_train, )

plt.figure(figsize=(16,12))
#plt.savefig('tree_diagram.pdf')
sklearn.tree.plot_tree(clf, fontsize=6, impurity=False);

# %%
correct_percent = np.sum(clf.predict(x_test) == y_test) / (features - split_idx)
print('Error percentage in validation: ', (1-correct_percent)*100)
# Out:
# Error percentage in validation:  25.465838509316775

# %%
# Now we start to tune the max_depth and min_sample_split in a completely brute-force way
correct_percent = np.zeros((12,12))

for i in range(1,11):
    for j in range(2,12):
        clf_tuned = sklearn.tree.DecisionTreeClassifier(max_depth=i, min_samples_split=j)
        clf_tuned = clf_tuned.fit(x_train, y_train)

        correct_percent[i,j] = np.sum(clf_tuned.predict(x_test) == y_test) / (features - split_idx)
        print('Error percentage for max_depth=', i, ' and min_sample_split=',j, ': ',(1-correct_percent[i,j])*100)
# Out:
# Error percentage for max_depth= 1  and min_sample_split= 2 :  22.360248447204967
# Error percentage for max_depth= 1  and min_sample_split= 3 :  22.360248447204967
# Error percentage for max_depth= 1  and min_sample_split= 4 :  22.360248447204967
# Error percentage for max_depth= 1  and min_sample_split= 5 :  22.360248447204967
# Error percentage for max_depth= 1  and min_sample_split= 6 :  22.360248447204967
# Error percentage for max_depth= 1  and min_sample_split= 7 :  22.360248447204967
# Error percentage for max_depth= 1  and min_sample_split= 8 :  22.360248447204967
# Error percentage for max_depth= 1  and min_sample_split= 9 :  22.360248447204967
# Error percentage for max_depth= 1  and min_sample_split= 10 :  22.360248447204967
# Error percentage for max_depth= 1  and min_sample_split= 11 :  22.360248447204967
# Error percentage for max_depth= 2  and min_sample_split= 2 :  22.981366459627328
# Error percentage for max_depth= 2  and min_sample_split= 3 :  22.360248447204967
# Error percentage for max_depth= 2  and min_sample_split= 4 :  22.981366459627328
# Error percentage for max_depth= 2  and min_sample_split= 5 :  22.360248447204967
# Error percentage for max_depth= 2  and min_sample_split= 6 :  22.981366459627328
# Error percentage for max_depth= 2  and min_sample_split= 7 :  22.981366459627328
# Error percentage for max_depth= 2  and min_sample_split= 8 :  22.981366459627328
# Error percentage for max_depth= 2  and min_sample_split= 9 :  22.360248447204967
# Error percentage for max_depth= 2  and min_sample_split= 10 :  22.981366459627328
# Error percentage for max_depth= 2  and min_sample_split= 11 :  22.360248447204967
# Error percentage for max_depth= 3  and min_sample_split= 2 :  20.496894409937894
# Error percentage for max_depth= 3  and min_sample_split= 3 :  20.496894409937894
# Error percentage for max_depth= 3  and min_sample_split= 4 :  20.496894409937894
# Error percentage for max_depth= 3  and min_sample_split= 5 :  20.496894409937894
# Error percentage for max_depth= 3  and min_sample_split= 6 :  20.496894409937894
# Error percentage for max_depth= 3  and min_sample_split= 7 :  22.360248447204967
# Error percentage for max_depth= 3  and min_sample_split= 8 :  22.360248447204967
# Error percentage for max_depth= 3  and min_sample_split= 9 :  20.496894409937894
# Error percentage for max_depth= 3  and min_sample_split= 10 :  20.496894409937894
# Error percentage for max_depth= 3  and min_sample_split= 11 :  22.360248447204967
# Error percentage for max_depth= 4  and min_sample_split= 2 :  22.360248447204967
# Error percentage for max_depth= 4  and min_sample_split= 3 :  22.981366459627328
# Error percentage for max_depth= 4  and min_sample_split= 4 :  20.496894409937894
# Error percentage for max_depth= 4  and min_sample_split= 5 :  22.360248447204967
# Error percentage for max_depth= 4  and min_sample_split= 6 :  21.739130434782606
# Error percentage for max_depth= 4  and min_sample_split= 7 :  22.360248447204967
# Error percentage for max_depth= 4  and min_sample_split= 8 :  22.981366459627328
# Error percentage for max_depth= 4  and min_sample_split= 9 :  21.739130434782606
# Error percentage for max_depth= 4  and min_sample_split= 10 :  21.118012422360245
# Error percentage for max_depth= 4  and min_sample_split= 11 :  21.739130434782606
# Error percentage for max_depth= 5  and min_sample_split= 2 :  20.496894409937894
# Error percentage for max_depth= 5  and min_sample_split= 3 :  20.496894409937894
# Error percentage for max_depth= 5  and min_sample_split= 4 :  20.496894409937894
# Error percentage for max_depth= 5  and min_sample_split= 5 :  20.496894409937894
# Error percentage for max_depth= 5  and min_sample_split= 6 :  20.496894409937894
# Error percentage for max_depth= 5  and min_sample_split= 7 :  20.496894409937894
# Error percentage for max_depth= 5  and min_sample_split= 8 :  20.496894409937894
# Error percentage for max_depth= 5  and min_sample_split= 9 :  20.496894409937894
# Error percentage for max_depth= 5  and min_sample_split= 10 :  20.496894409937894
# Error percentage for max_depth= 5  and min_sample_split= 11 :  20.496894409937894
# Error percentage for max_depth= 6  and min_sample_split= 2 :  21.739130434782606
# Error percentage for max_depth= 6  and min_sample_split= 3 :  22.360248447204967
# Error percentage for max_depth= 6  and min_sample_split= 4 :  22.360248447204967
# Error percentage for max_depth= 6  and min_sample_split= 5 :  21.739130434782606
# Error percentage for max_depth= 6  and min_sample_split= 6 :  21.739130434782606
# Error percentage for max_depth= 6  and min_sample_split= 7 :  21.739130434782606
# Error percentage for max_depth= 6  and min_sample_split= 8 :  21.739130434782606
# Error percentage for max_depth= 6  and min_sample_split= 9 :  21.739130434782606
# Error percentage for max_depth= 6  and min_sample_split= 10 :  20.496894409937894
# Error percentage for max_depth= 6  and min_sample_split= 11 :  21.118012422360245
# Error percentage for max_depth= 7  and min_sample_split= 2 :  20.496894409937894
# Error percentage for max_depth= 7  and min_sample_split= 3 :  21.118012422360245
# Error percentage for max_depth= 7  and min_sample_split= 4 :  22.981366459627328
# Error percentage for max_depth= 7  and min_sample_split= 5 :  22.360248447204967
# Error percentage for max_depth= 7  and min_sample_split= 6 :  23.60248447204969
# Error percentage for max_depth= 7  and min_sample_split= 7 :  21.739130434782606
# Error percentage for max_depth= 7  and min_sample_split= 8 :  22.360248447204967
# Error percentage for max_depth= 7  and min_sample_split= 9 :  21.118012422360245
# Error percentage for max_depth= 7  and min_sample_split= 10 :  22.360248447204967
# Error percentage for max_depth= 7  and min_sample_split= 11 :  19.875776397515533
# Error percentage for max_depth= 8  and min_sample_split= 2 :  22.360248447204967
# Error percentage for max_depth= 8  and min_sample_split= 3 :  22.360248447204967
# Error percentage for max_depth= 8  and min_sample_split= 4 :  22.981366459627328
# Error percentage for max_depth= 8  and min_sample_split= 5 :  22.981366459627328
# Error percentage for max_depth= 8  and min_sample_split= 6 :  22.981366459627328
# Error percentage for max_depth= 8  and min_sample_split= 7 :  22.360248447204967
# Error percentage for max_depth= 8  and min_sample_split= 8 :  21.118012422360245
# Error percentage for max_depth= 8  and min_sample_split= 9 :  22.360248447204967
# Error percentage for max_depth= 8  and min_sample_split= 10 :  22.360248447204967
# Error percentage for max_depth= 8  and min_sample_split= 11 :  21.118012422360245
# Error percentage for max_depth= 9  and min_sample_split= 2 :  26.086956521739136
# Error percentage for max_depth= 9  and min_sample_split= 3 :  21.118012422360245
# Error percentage for max_depth= 9  and min_sample_split= 4 :  25.465838509316775
# Error percentage for max_depth= 9  and min_sample_split= 5 :  22.981366459627328
# Error percentage for max_depth= 9  and min_sample_split= 6 :  21.118012422360245
# Error percentage for max_depth= 9  and min_sample_split= 7 :  22.981366459627328
# Error percentage for max_depth= 9  and min_sample_split= 8 :  25.465838509316775
# Error percentage for max_depth= 9  and min_sample_split= 9 :  20.496894409937894
# Error percentage for max_depth= 9  and min_sample_split= 10 :  19.875776397515533
# Error percentage for max_depth= 9  and min_sample_split= 11 :  21.118012422360245
# Error percentage for max_depth= 10  and min_sample_split= 2 :  24.22360248447205
# Error percentage for max_depth= 10  and min_sample_split= 3 :  23.60248447204969
# Error percentage for max_depth= 10  and min_sample_split= 4 :  19.875776397515533
# Error percentage for max_depth= 10  and min_sample_split= 5 :  21.118012422360245
# Error percentage for max_depth= 10  and min_sample_split= 6 :  22.981366459627328
# Error percentage for max_depth= 10  and min_sample_split= 7 :  21.118012422360245
# Error percentage for max_depth= 10  and min_sample_split= 8 :  24.22360248447205
# Error percentage for max_depth= 10  and min_sample_split= 9 :  22.360248447204967
# Error percentage for max_depth= 10  and min_sample_split= 10 :  22.981366459627328
# Error percentage for max_depth= 10  and min_sample_split= 11 :  20.496894409937894

# %% [markdown]
# ## It looks like the simplest classifer that achieves the minimum error has a max depth of 5 and a min sample split of 5. Plotted below is the tree structure...

# %%
clf_opt = sklearn.tree.DecisionTreeClassifier(max_depth=5, min_samples_split=5)
clf_opt = clf_tuned.fit(x_train, y_train)

plt.figure(figsize=(16,12))
sklearn.tree.plot_tree(clf_opt, fontsize=6, impurity=False);

# %% [markdown]
# # Random Forest Models

# %%
from sklearn import ensemble
tot = 400
correct_percent = np.zeros((tot,))

for i in range(tot):

    rf_clf = sklearn.ensemble.RandomForestClassifier(n_estimators=int(i)+1, max_depth=5, min_samples_split=5)
    rf_clf.fit(x_train, y_train)

    correct_percent[i] = np.sum(rf_clf.predict(x_test) == y_test) / (features - split_idx)
    print('Error percentage in validation: ', (1-correct_percent[i])*100, 'for number of trees: ',int(i)+1)
# Out:
# Error percentage in validation:  24.84472049689441 for number of trees:  1
# Error percentage in validation:  21.739130434782606 for number of trees:  2
# Error percentage in validation:  26.708074534161486 for number of trees:  3
# Error percentage in validation:  24.22360248447205 for number of trees:  4
# Error percentage in validation:  18.012422360248447 for number of trees:  5
# Error percentage in validation:  20.496894409937894 for number of trees:  6
# Error percentage in validation:  20.496894409937894 for number of trees:  7
# Error percentage in validation:  18.633540372670808 for number of trees:  8
# Error percentage in validation:  20.496894409937894 for number of trees:  9
# Error percentage in validation:  16.770186335403725 for number of trees:  10
# Error percentage in validation:  21.739130434782606 for number of trees:  11
# Error percentage in validation:  18.012422360248447 for number of trees:  12
# Error percentage in validation:  18.633540372670808 for number of trees:  13
# Error percentage in validation:  17.391304347826086 for number of trees:  14
# Error percentage in validation:  19.254658385093173 for number of trees:  15
# Error percentage in validation:  19.254658385093173 for number of trees:  16
# Error percentage in validation:  18.633540372670808 for number of trees:  17
# Error percentage in validation:  17.391304347826086 for number of trees:  18
# Error percentage in validation:  16.770186335403725 for number of trees:  19
# Error percentage in validation:  18.633540372670808 for number of trees:  20
# Error percentage in validation:  14.90683229813664 for number of trees:  21
# Error percentage in validation:  18.633540372670808 for number of trees:  22
# Error percentage in validation:  17.391304347826086 for number of trees:  23
# Error percentage in validation:  16.149068322981364 for number of trees:  24
# Error percentage in validation:  18.012422360248447 for number of trees:  25
# Error percentage in validation:  16.770186335403725 for number of trees:  26
# Error percentage in validation:  17.391304347826086 for number of trees:  27
# Error percentage in validation:  16.770186335403725 for number of trees:  28
# Error percentage in validation:  18.633540372670808 for number of trees:  29
# Error percentage in validation:  19.254658385093173 for number of trees:  30
# Error percentage in validation:  18.012422360248447 for number of trees:  31
# Error percentage in validation:  18.633540372670808 for number of trees:  32
# Error percentage in validation:  18.012422360248447 for number of trees:  33
# Error percentage in validation:  19.254658385093173 for number of trees:  34
# Error percentage in validation:  18.633540372670808 for number of trees:  35
# Error percentage in validation:  16.149068322981364 for number of trees:  36
# Error percentage in validation:  18.633540372670808 for number of trees:  37
# Error percentage in validation:  18.012422360248447 for number of trees:  38
# Error percentage in validation:  18.012422360248447 for number of trees:  39
# Error percentage in validation:  18.633540372670808 for number of trees:  40
# Error percentage in validation:  18.633540372670808 for number of trees:  41
# Error percentage in validation:  16.770186335403725 for number of trees:  42
# Error percentage in validation:  16.149068322981364 for number of trees:  43
# Error percentage in validation:  18.633540372670808 for number of trees:  44
# Error percentage in validation:  17.391304347826086 for number of trees:  45
# Error percentage in validation:  15.527950310559003 for number of trees:  46
# Error percentage in validation:  18.633540372670808 for number of trees:  47
# Error percentage in validation:  18.012422360248447 for number of trees:  48
# Error percentage in validation:  19.254658385093173 for number of trees:  49
# Error percentage in validation:  17.391304347826086 for number of trees:  50
# Error percentage in validation:  17.391304347826086 for number of trees:  51
# Error percentage in validation:  18.012422360248447 for number of trees:  52
# Error percentage in validation:  18.633540372670808 for number of trees:  53
# Error percentage in validation:  18.012422360248447 for number of trees:  54
# Error percentage in validation:  17.391304347826086 for number of trees:  55
# Error percentage in validation:  18.012422360248447 for number of trees:  56
# Error percentage in validation:  18.633540372670808 for number of trees:  57
# Error percentage in validation:  17.391304347826086 for number of trees:  58
# Error percentage in validation:  16.149068322981364 for number of trees:  59
# Error percentage in validation:  16.770186335403725 for number of trees:  60
# Error percentage in validation:  16.149068322981364 for number of trees:  61
# Error percentage in validation:  18.633540372670808 for number of trees:  62
# Error percentage in validation:  17.391304347826086 for number of trees:  63
# Error percentage in validation:  18.012422360248447 for number of trees:  64
# Error percentage in validation:  15.527950310559003 for number of trees:  65
# Error percentage in validation:  17.391304347826086 for number of trees:  66
# Error percentage in validation:  16.770186335403725 for number of trees:  67
# Error percentage in validation:  16.770186335403725 for number of trees:  68
# Error percentage in validation:  18.012422360248447 for number of trees:  69
# Error percentage in validation:  19.254658385093173 for number of trees:  70
# Error percentage in validation:  16.770186335403725 for number of trees:  71
# Error percentage in validation:  17.391304347826086 for number of trees:  72
# Error percentage in validation:  18.012422360248447 for number of trees:  73
# Error percentage in validation:  17.391304347826086 for number of trees:  74
# Error percentage in validation:  18.633540372670808 for number of trees:  75
# Error percentage in validation:  18.012422360248447 for number of trees:  76
# Error percentage in validation:  19.875776397515533 for number of trees:  77
# Error percentage in validation:  17.391304347826086 for number of trees:  78
# Error percentage in validation:  18.012422360248447 for number of trees:  79
# Error percentage in validation:  16.770186335403725 for number of trees:  80
# Error percentage in validation:  18.633540372670808 for number of trees:  81
# Error percentage in validation:  17.391304347826086 for number of trees:  82
# Error percentage in validation:  19.254658385093173 for number of trees:  83
# Error percentage in validation:  16.770186335403725 for number of trees:  84
# Error percentage in validation:  19.254658385093173 for number of trees:  85
# Error percentage in validation:  19.254658385093173 for number of trees:  86
# Error percentage in validation:  18.012422360248447 for number of trees:  87
# Error percentage in validation:  17.391304347826086 for number of trees:  88
# Error percentage in validation:  18.012422360248447 for number of trees:  89
# Error percentage in validation:  18.012422360248447 for number of trees:  90
# Error percentage in validation:  16.770186335403725 for number of trees:  91
# Error percentage in validation:  16.770186335403725 for number of trees:  92
# Error percentage in validation:  17.391304347826086 for number of trees:  93
# Error percentage in validation:  18.633540372670808 for number of trees:  94
# Error percentage in validation:  18.012422360248447 for number of trees:  95
# Error percentage in validation:  18.012422360248447 for number of trees:  96
# Error percentage in validation:  18.012422360248447 for number of trees:  97
# Error percentage in validation:  17.391304347826086 for number of trees:  98
# Error percentage in validation:  18.633540372670808 for number of trees:  99
# Error percentage in validation:  18.012422360248447 for number of trees:  100
# Error percentage in validation:  18.633540372670808 for number of trees:  101
# Error percentage in validation:  19.254658385093173 for number of trees:  102
# Error percentage in validation:  18.633540372670808 for number of trees:  103
# Error percentage in validation:  18.012422360248447 for number of trees:  104
# Error percentage in validation:  18.633540372670808 for number of trees:  105
# Error percentage in validation:  17.391304347826086 for number of trees:  106
# Error percentage in validation:  18.633540372670808 for number of trees:  107
# Error percentage in validation:  19.254658385093173 for number of trees:  108
# Error percentage in validation:  14.90683229813664 for number of trees:  109
# Error percentage in validation:  16.149068322981364 for number of trees:  110
# Error percentage in validation:  18.012422360248447 for number of trees:  111
# Error percentage in validation:  17.391304347826086 for number of trees:  112
# Error percentage in validation:  17.391304347826086 for number of trees:  113
# Error percentage in validation:  18.012422360248447 for number of trees:  114
# Error percentage in validation:  17.391304347826086 for number of trees:  115
# Error percentage in validation:  16.149068322981364 for number of trees:  116
# Error percentage in validation:  16.149068322981364 for number of trees:  117
# Error percentage in validation:  18.012422360248447 for number of trees:  118
# Error percentage in validation:  16.770186335403725 for number of trees:  119
# Error percentage in validation:  16.149068322981364 for number of trees:  120
# Error percentage in validation:  18.012422360248447 for number of trees:  121
# Error percentage in validation:  17.391304347826086 for number of trees:  122
# Error percentage in validation:  16.770186335403725 for number of trees:  123
# Error percentage in validation:  16.770186335403725 for number of trees:  124
# Error percentage in validation:  19.254658385093173 for number of trees:  125
# Error percentage in validation:  15.527950310559003 for number of trees:  126
# Error percentage in validation:  18.633540372670808 for number of trees:  127
# Error percentage in validation:  15.527950310559003 for number of trees:  128
# Error percentage in validation:  16.770186335403725 for number of trees:  129
# Error percentage in validation:  17.391304347826086 for number of trees:  130
# Error percentage in validation:  17.391304347826086 for number of trees:  131
# Error percentage in validation:  18.633540372670808 for number of trees:  132
# Error percentage in validation:  17.391304347826086 for number of trees:  133
# Error percentage in validation:  15.527950310559003 for number of trees:  134
# Error percentage in validation:  16.149068322981364 for number of trees:  135
# Error percentage in validation:  16.770186335403725 for number of trees:  136
# Error percentage in validation:  18.633540372670808 for number of trees:  137
# Error percentage in validation:  18.633540372670808 for number of trees:  138
# Error percentage in validation:  18.012422360248447 for number of trees:  139
# Error percentage in validation:  17.391304347826086 for number of trees:  140
# Error percentage in validation:  16.770186335403725 for number of trees:  141
# Error percentage in validation:  18.012422360248447 for number of trees:  142
# Error percentage in validation:  16.149068322981364 for number of trees:  143
# Error percentage in validation:  16.770186335403725 for number of trees:  144
# Error percentage in validation:  18.012422360248447 for number of trees:  145
# Error percentage in validation:  18.012422360248447 for number of trees:  146
# Error percentage in validation:  18.633540372670808 for number of trees:  147
# Error percentage in validation:  17.391304347826086 for number of trees:  148
# Error percentage in validation:  18.633540372670808 for number of trees:  149
# Error percentage in validation:  16.149068322981364 for number of trees:  150
# Error percentage in validation:  17.391304347826086 for number of trees:  151
# Error percentage in validation:  18.633540372670808 for number of trees:  152
# Error percentage in validation:  18.012422360248447 for number of trees:  153
# Error percentage in validation:  17.391304347826086 for number of trees:  154
# Error percentage in validation:  18.012422360248447 for number of trees:  155
# Error percentage in validation:  17.391304347826086 for number of trees:  156
# Error percentage in validation:  17.391304347826086 for number of trees:  157
# Error percentage in validation:  18.012422360248447 for number of trees:  158
# Error percentage in validation:  18.012422360248447 for number of trees:  159
# Error percentage in validation:  18.012422360248447 for number of trees:  160
# Error percentage in validation:  17.391304347826086 for number of trees:  161
# Error percentage in validation:  16.149068322981364 for number of trees:  162
# Error percentage in validation:  16.149068322981364 for number of trees:  163
# Error percentage in validation:  17.391304347826086 for number of trees:  164
# Error percentage in validation:  15.527950310559003 for number of trees:  165
# Error percentage in validation:  18.012422360248447 for number of trees:  166
# Error percentage in validation:  18.633540372670808 for number of trees:  167
# Error percentage in validation:  17.391304347826086 for number of trees:  168
# Error percentage in validation:  16.149068322981364 for number of trees:  169
# Error percentage in validation:  18.012422360248447 for number of trees:  170
# Error percentage in validation:  17.391304347826086 for number of trees:  171
# Error percentage in validation:  17.391304347826086 for number of trees:  172
# Error percentage in validation:  17.391304347826086 for number of trees:  173
# Error percentage in validation:  16.149068322981364 for number of trees:  174
# Error percentage in validation:  19.875776397515533 for number of trees:  175
# Error percentage in validation:  15.527950310559003 for number of trees:  176
# Error percentage in validation:  16.149068322981364 for number of trees:  177
# Error percentage in validation:  18.012422360248447 for number of trees:  178
# Error percentage in validation:  18.012422360248447 for number of trees:  179
# Error percentage in validation:  16.770186335403725 for number of trees:  180
# Error percentage in validation:  18.012422360248447 for number of trees:  181
# Error percentage in validation:  18.012422360248447 for number of trees:  182
# Error percentage in validation:  17.391304347826086 for number of trees:  183
# Error percentage in validation:  16.770186335403725 for number of trees:  184
# Error percentage in validation:  16.770186335403725 for number of trees:  185
# Error percentage in validation:  18.012422360248447 for number of trees:  186
# Error percentage in validation:  18.012422360248447 for number of trees:  187
# Error percentage in validation:  17.391304347826086 for number of trees:  188
# Error percentage in validation:  18.012422360248447 for number of trees:  189
# Error percentage in validation:  18.012422360248447 for number of trees:  190
# Error percentage in validation:  19.254658385093173 for number of trees:  191
# Error percentage in validation:  16.149068322981364 for number of trees:  192
# Error percentage in validation:  17.391304347826086 for number of trees:  193
# Error percentage in validation:  16.149068322981364 for number of trees:  194
# Error percentage in validation:  18.012422360248447 for number of trees:  195
# Error percentage in validation:  18.012422360248447 for number of trees:  196
# Error percentage in validation:  16.149068322981364 for number of trees:  197
# Error percentage in validation:  18.012422360248447 for number of trees:  198
# Error percentage in validation:  16.770186335403725 for number of trees:  199
# Error percentage in validation:  16.149068322981364 for number of trees:  200
# Error percentage in validation:  19.875776397515533 for number of trees:  201
# Error percentage in validation:  18.012422360248447 for number of trees:  202
# Error percentage in validation:  16.149068322981364 for number of trees:  203
# Error percentage in validation:  16.149068322981364 for number of trees:  204
# Error percentage in validation:  16.770186335403725 for number of trees:  205
# Error percentage in validation:  16.149068322981364 for number of trees:  206
# Error percentage in validation:  18.012422360248447 for number of trees:  207
# Error percentage in validation:  18.633540372670808 for number of trees:  208
# Error percentage in validation:  19.254658385093173 for number of trees:  209
# Error percentage in validation:  17.391304347826086 for number of trees:  210
# Error percentage in validation:  18.633540372670808 for number of trees:  211
# Error percentage in validation:  18.633540372670808 for number of trees:  212
# Error percentage in validation:  17.391304347826086 for number of trees:  213
# Error percentage in validation:  16.770186335403725 for number of trees:  214
# Error percentage in validation:  18.012422360248447 for number of trees:  215
# Error percentage in validation:  18.012422360248447 for number of trees:  216
# Error percentage in validation:  18.012422360248447 for number of trees:  217
# Error percentage in validation:  18.633540372670808 for number of trees:  218
# Error percentage in validation:  20.496894409937894 for number of trees:  219
# Error percentage in validation:  18.012422360248447 for number of trees:  220
# Error percentage in validation:  18.012422360248447 for number of trees:  221
# Error percentage in validation:  18.012422360248447 for number of trees:  222
# Error percentage in validation:  16.770186335403725 for number of trees:  223
# Error percentage in validation:  16.770186335403725 for number of trees:  224
# Error percentage in validation:  18.633540372670808 for number of trees:  225
# Error percentage in validation:  16.149068322981364 for number of trees:  226
# Error percentage in validation:  17.391304347826086 for number of trees:  227
# Error percentage in validation:  16.770186335403725 for number of trees:  228
# Error percentage in validation:  17.391304347826086 for number of trees:  229
# Error percentage in validation:  18.012422360248447 for number of trees:  230
# Error percentage in validation:  16.770186335403725 for number of trees:  231
# Error percentage in validation:  18.012422360248447 for number of trees:  232
# Error percentage in validation:  18.012422360248447 for number of trees:  233
# Error percentage in validation:  18.633540372670808 for number of trees:  234
# Error percentage in validation:  19.254658385093173 for number of trees:  235
# Error percentage in validation:  16.770186335403725 for number of trees:  236
# Error percentage in validation:  16.149068322981364 for number of trees:  237
# Error percentage in validation:  17.391304347826086 for number of trees:  238
# Error percentage in validation:  17.391304347826086 for number of trees:  239
# Error percentage in validation:  16.149068322981364 for number of trees:  240
# Error percentage in validation:  16.770186335403725 for number of trees:  241
# Error percentage in validation:  17.391304347826086 for number of trees:  242
# Error percentage in validation:  16.770186335403725 for number of trees:  243
# Error percentage in validation:  18.012422360248447 for number of trees:  244
# Error percentage in validation:  17.391304347826086 for number of trees:  245
# Error percentage in validation:  18.012422360248447 for number of trees:  246
# Error percentage in validation:  18.012422360248447 for number of trees:  247
# Error percentage in validation:  18.012422360248447 for number of trees:  248
# Error percentage in validation:  17.391304347826086 for number of trees:  249
# Error percentage in validation:  16.770186335403725 for number of trees:  250
# Error percentage in validation:  17.391304347826086 for number of trees:  251
# Error percentage in validation:  17.391304347826086 for number of trees:  252
# Error percentage in validation:  19.254658385093173 for number of trees:  253
# Error percentage in validation:  16.770186335403725 for number of trees:  254
# Error percentage in validation:  16.149068322981364 for number of trees:  255
# Error percentage in validation:  19.254658385093173 for number of trees:  256
# Error percentage in validation:  18.012422360248447 for number of trees:  257
# Error percentage in validation:  18.012422360248447 for number of trees:  258
# Error percentage in validation:  17.391304347826086 for number of trees:  259
# Error percentage in validation:  18.012422360248447 for number of trees:  260
# Error percentage in validation:  18.012422360248447 for number of trees:  261
# Error percentage in validation:  18.633540372670808 for number of trees:  262
# Error percentage in validation:  16.149068322981364 for number of trees:  263
# Error percentage in validation:  17.391304347826086 for number of trees:  264
# Error percentage in validation:  17.391304347826086 for number of trees:  265
# Error percentage in validation:  18.012422360248447 for number of trees:  266
# Error percentage in validation:  15.527950310559003 for number of trees:  267
# Error percentage in validation:  17.391304347826086 for number of trees:  268
# Error percentage in validation:  18.012422360248447 for number of trees:  269
# Error percentage in validation:  16.149068322981364 for number of trees:  270
# Error percentage in validation:  17.391304347826086 for number of trees:  271
# Error percentage in validation:  16.770186335403725 for number of trees:  272
# Error percentage in validation:  18.633540372670808 for number of trees:  273
# Error percentage in validation:  18.012422360248447 for number of trees:  274
# Error percentage in validation:  18.012422360248447 for number of trees:  275
# Error percentage in validation:  18.012422360248447 for number of trees:  276
# Error percentage in validation:  16.149068322981364 for number of trees:  277
# Error percentage in validation:  19.254658385093173 for number of trees:  278
# Error percentage in validation:  17.391304347826086 for number of trees:  279
# Error percentage in validation:  17.391304347826086 for number of trees:  280
# Error percentage in validation:  16.770186335403725 for number of trees:  281
# Error percentage in validation:  19.254658385093173 for number of trees:  282
# Error percentage in validation:  17.391304347826086 for number of trees:  283
# Error percentage in validation:  18.012422360248447 for number of trees:  284
# Error percentage in validation:  17.391304347826086 for number of trees:  285
# Error percentage in validation:  18.633540372670808 for number of trees:  286
# Error percentage in validation:  19.254658385093173 for number of trees:  287
# Error percentage in validation:  16.770186335403725 for number of trees:  288
# Error percentage in validation:  16.770186335403725 for number of trees:  289
# Error percentage in validation:  16.770186335403725 for number of trees:  290
# Error percentage in validation:  18.012422360248447 for number of trees:  291
# Error percentage in validation:  16.149068322981364 for number of trees:  292
# Error percentage in validation:  18.012422360248447 for number of trees:  293
# Error percentage in validation:  17.391304347826086 for number of trees:  294
# Error percentage in validation:  16.770186335403725 for number of trees:  295
# Error percentage in validation:  17.391304347826086 for number of trees:  296
# Error percentage in validation:  18.012422360248447 for number of trees:  297
# Error percentage in validation:  18.633540372670808 for number of trees:  298
# Error percentage in validation:  18.012422360248447 for number of trees:  299
# Error percentage in validation:  18.633540372670808 for number of trees:  300
# Error percentage in validation:  17.391304347826086 for number of trees:  301
# Error percentage in validation:  18.012422360248447 for number of trees:  302
# Error percentage in validation:  17.391304347826086 for number of trees:  303
# Error percentage in validation:  16.149068322981364 for number of trees:  304
# Error percentage in validation:  17.391304347826086 for number of trees:  305
# Error percentage in validation:  18.633540372670808 for number of trees:  306
# Error percentage in validation:  18.633540372670808 for number of trees:  307
# Error percentage in validation:  16.770186335403725 for number of trees:  308
# Error percentage in validation:  18.633540372670808 for number of trees:  309
# Error percentage in validation:  16.770186335403725 for number of trees:  310
# Error percentage in validation:  18.633540372670808 for number of trees:  311
# Error percentage in validation:  16.770186335403725 for number of trees:  312
# Error percentage in validation:  17.391304347826086 for number of trees:  313
# Error percentage in validation:  18.012422360248447 for number of trees:  314
# Error percentage in validation:  19.254658385093173 for number of trees:  315
# Error percentage in validation:  18.633540372670808 for number of trees:  316
# Error percentage in validation:  16.770186335403725 for number of trees:  317
# Error percentage in validation:  17.391304347826086 for number of trees:  318
# Error percentage in validation:  15.527950310559003 for number of trees:  319
# Error percentage in validation:  17.391304347826086 for number of trees:  320
# Error percentage in validation:  16.770186335403725 for number of trees:  321
# Error percentage in validation:  18.012422360248447 for number of trees:  322
# Error percentage in validation:  16.149068322981364 for number of trees:  323
# Error percentage in validation:  18.633540372670808 for number of trees:  324
# Error percentage in validation:  18.012422360248447 for number of trees:  325
# Error percentage in validation:  18.012422360248447 for number of trees:  326
# Error percentage in validation:  18.633540372670808 for number of trees:  327
# Error percentage in validation:  17.391304347826086 for number of trees:  328
# Error percentage in validation:  17.391304347826086 for number of trees:  329
# Error percentage in validation:  17.391304347826086 for number of trees:  330
# Error percentage in validation:  17.391304347826086 for number of trees:  331
# Error percentage in validation:  17.391304347826086 for number of trees:  332
# Error percentage in validation:  17.391304347826086 for number of trees:  333
# Error percentage in validation:  18.633540372670808 for number of trees:  334
# Error percentage in validation:  17.391304347826086 for number of trees:  335
# Error percentage in validation:  16.770186335403725 for number of trees:  336
# Error percentage in validation:  17.391304347826086 for number of trees:  337
# Error percentage in validation:  16.770186335403725 for number of trees:  338
# Error percentage in validation:  16.770186335403725 for number of trees:  339
# Error percentage in validation:  18.633540372670808 for number of trees:  340
# Error percentage in validation:  17.391304347826086 for number of trees:  341
# Error percentage in validation:  15.527950310559003 for number of trees:  342
# Error percentage in validation:  18.012422360248447 for number of trees:  343
# Error percentage in validation:  16.149068322981364 for number of trees:  344
# Error percentage in validation:  16.770186335403725 for number of trees:  345
# Error percentage in validation:  17.391304347826086 for number of trees:  346
# Error percentage in validation:  16.149068322981364 for number of trees:  347
# Error percentage in validation:  17.391304347826086 for number of trees:  348
# Error percentage in validation:  16.770186335403725 for number of trees:  349
# Error percentage in validation:  17.391304347826086 for number of trees:  350
# Error percentage in validation:  17.391304347826086 for number of trees:  351
# Error percentage in validation:  18.012422360248447 for number of trees:  352
# Error percentage in validation:  18.012422360248447 for number of trees:  353
# Error percentage in validation:  18.012422360248447 for number of trees:  354
# Error percentage in validation:  18.633540372670808 for number of trees:  355
# Error percentage in validation:  17.391304347826086 for number of trees:  356
# Error percentage in validation:  17.391304347826086 for number of trees:  357
# Error percentage in validation:  18.012422360248447 for number of trees:  358
# Error percentage in validation:  18.012422360248447 for number of trees:  359
# Error percentage in validation:  17.391304347826086 for number of trees:  360
# Error percentage in validation:  17.391304347826086 for number of trees:  361
# Error percentage in validation:  16.149068322981364 for number of trees:  362
# Error percentage in validation:  17.391304347826086 for number of trees:  363
# Error percentage in validation:  17.391304347826086 for number of trees:  364
# Error percentage in validation:  17.391304347826086 for number of trees:  365
# Error percentage in validation:  17.391304347826086 for number of trees:  366
# Error percentage in validation:  17.391304347826086 for number of trees:  367
# Error percentage in validation:  17.391304347826086 for number of trees:  368
# Error percentage in validation:  18.012422360248447 for number of trees:  369
# Error percentage in validation:  17.391304347826086 for number of trees:  370
# Error percentage in validation:  16.770186335403725 for number of trees:  371
# Error percentage in validation:  16.149068322981364 for number of trees:  372
# Error percentage in validation:  18.012422360248447 for number of trees:  373
# Error percentage in validation:  18.012422360248447 for number of trees:  374
# Error percentage in validation:  17.391304347826086 for number of trees:  375
# Error percentage in validation:  18.012422360248447 for number of trees:  376
# Error percentage in validation:  16.149068322981364 for number of trees:  377
# Error percentage in validation:  17.391304347826086 for number of trees:  378
# Error percentage in validation:  16.770186335403725 for number of trees:  379
# Error percentage in validation:  18.012422360248447 for number of trees:  380
# Error percentage in validation:  18.012422360248447 for number of trees:  381
# Error percentage in validation:  18.633540372670808 for number of trees:  382
# Error percentage in validation:  18.633540372670808 for number of trees:  383
# Error percentage in validation:  16.770186335403725 for number of trees:  384
# Error percentage in validation:  17.391304347826086 for number of trees:  385
# Error percentage in validation:  17.391304347826086 for number of trees:  386
# Error percentage in validation:  17.391304347826086 for number of trees:  387
# Error percentage in validation:  18.633540372670808 for number of trees:  388
# Error percentage in validation:  15.527950310559003 for number of trees:  389
# Error percentage in validation:  17.391304347826086 for number of trees:  390
# Error percentage in validation:  16.770186335403725 for number of trees:  391
# Error percentage in validation:  18.012422360248447 for number of trees:  392
# Error percentage in validation:  18.633540372670808 for number of trees:  393
# Error percentage in validation:  18.012422360248447 for number of trees:  394
# Error percentage in validation:  16.149068322981364 for number of trees:  395
# Error percentage in validation:  18.012422360248447 for number of trees:  396
# Error percentage in validation:  17.391304347826086 for number of trees:  397
# Error percentage in validation:  17.391304347826086 for number of trees:  398
# Error percentage in validation:  16.770186335403725 for number of trees:  399
# Error percentage in validation:  16.770186335403725 for number of trees:  400

# %%
XX = np.zeros((tot,))
for i in range(tot):
    XX[i] = int(i)+1
plt.plot(XX, correct_percent, '.')
plt.ylabel('Percent correct')
plt.xlabel('Trees used in RF model')
#plt.savefig('RF_error3.pdf')
# Out:
# Text(0.5, 0, 'Trees used in RF model')
